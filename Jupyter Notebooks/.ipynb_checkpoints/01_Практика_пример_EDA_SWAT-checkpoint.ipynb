# %% [markdown]
# <h1> Материалы курса "Анализ данных в инфромационной безопасности" </h1>
#
# Анализ данных работы промышленной установки Сингапурского университета (SUTD)
#
# https://itrust.sutd.edu.sg/itrust-labs-home/itrust-labs_swat/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.__version__
# Out:
# '3.0.2'

# %% [markdown]
# # 1. Чтение, первичное преобразование и сохранение данных

# %%
#filename = 'SWaT_Dataset_Normal_v1.xlsx'
filename = 'SWaT_Dataset_Normal_v1.csv'

pd.read_csv(filename, nrows=10, decimal=',')
# Out:
#                 Timestamp  FIT101    LIT101  MV101  P101  P102    AIT201  \
# 0   22/12/2015 4:30:00 PM       0  124.3135      1     1     1  251.9226
# 1   22/12/2015 4:30:01 PM       0  124.3920      1     1     1  251.9226
# 2   22/12/2015 4:30:02 PM       0  124.4705      1     1     1  251.9226
# 3   22/12/2015 4:30:03 PM       0  124.6668      1     1     1  251.9226
# 4   22/12/2015 4:30:04 PM       0  124.5098      1     1     1  251.9226
# 5   22/12/2015 4:30:05 PM       0  123.9210      1     1     1  251.9226
# 6   22/12/2015 4:30:06 PM       0  123.5284      1     1     1  251.9226
# 7   22/12/2015 4:30:07 PM       0  123.4107      1     1     1  251.9226
# 8   22/12/2015 4:30:08 PM       0  123.2144      1     1     1  251.9226
# 9   22/12/2015 4:30:09 PM       0  123.3322      1     1     1  251.9226
#
#      AIT202    AIT203  FIT201  ...  P501  P502    PIT501  PIT502  PIT503  \
# 0  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 1  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 2  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 3  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 4  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 5  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 6  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 7  8.313446  312.7916       0  ...     1     1  9.100231       0  3.3485
# 8  8.312805  312.7916       0  ...     1     1  9.100231       0  3.3485
# 9  8.310242  312.7916       0  ...     1     1  9.100231       0  3.3485
#
#      FIT601  P601  P602  P603  Normal/Attack
# 0  0.000256     1     1     1         Normal
# 1  0.000256     1     1     1         Normal
# 2  0.000256     1     1     1         Normal
# 3  0.000256     1     1     1         Normal
# 4  0.000256     1     1     1         Normal
# 5  0.000256     1     1     1         Normal
# 6  0.000256     1     1     1         Normal
# 7  0.000256     1     1     1         Normal
# 8  0.000256     1     1     1         Normal
# 9  0.000256     1     1     1         Normal
#
# [10 rows x 53 columns]

# %%
# %%time


df = pd.read_csv(
    filename, nrows=20_000,
    header=0,
    decimal=","
    #index_col=0
)
df
# Out:
# CPU times: total: 62.5 ms
# Wall time: 65.1 ms
#                      Timestamp    FIT101    LIT101  MV101  P101  P102  \
# 0        22/12/2015 4:30:00 PM  0.000000  124.3135      1     1     1
# 1        22/12/2015 4:30:01 PM  0.000000  124.3920      1     1     1
# 2        22/12/2015 4:30:02 PM  0.000000  124.4705      1     1     1
# 3        22/12/2015 4:30:03 PM  0.000000  124.6668      1     1     1
# 4        22/12/2015 4:30:04 PM  0.000000  124.5098      1     1     1
# ...                        ...       ...       ...    ...   ...   ...
# 19995   22/12/2015 10:03:15 PM  2.443391  503.4166      2     2     1
# 19996   22/12/2015 10:03:16 PM  2.427057  503.4559      2     2     1
# 19997   22/12/2015 10:03:17 PM  2.424815  503.2596      2     2     1
# 19998   22/12/2015 10:03:18 PM  2.423854  503.2989      2     2     1
# 19999   22/12/2015 10:03:19 PM  2.423854  503.2204      2     2     1
#
#          AIT201    AIT202    AIT203    FIT201  ...  P501  P502      PIT501  \
# 0      251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 1      251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 2      251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 3      251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 4      251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# ...         ...       ...       ...       ...  ...   ...   ...         ...
# 19995  261.2791  8.339080  437.4263  2.460898  ...     2     1  254.229700
# 19996  261.2791  8.339080  437.4263  2.460898  ...     2     1  254.229700
# 19997  261.2791  8.339080  437.4007  2.460898  ...     2     1  254.229700
# 19998  261.2791  8.339080  437.3494  2.463204  ...     2     1  254.229700
# 19999  261.2791  8.339080  437.2212  2.463204  ...     2     1  254.229700
#
#          PIT502    PIT503    FIT601  P601  P602  P603  Normal/Attack
# 0      0.000000    3.3485  0.000256     1     1     1         Normal
# 1      0.000000    3.3485  0.000256     1     1     1         Normal
# 2      0.000000    3.3485  0.000256     1     1     1         Normal
# 3      0.000000    3.3485  0.000256     1     1     1         Normal
# 4      0.000000    3.3485  0.000256     1     1     1         Normal
# ...         ...       ...       ...   ...   ...   ...            ...
# 19995  1.105309  193.3479  0.000128     1     1     1         Normal
# 19996  1.057252  193.3479  0.000128     1     1     1         Normal
# 19997  1.057252  193.3479  0.000128     1     1     1         Normal
# 19998  1.057252  193.3479  0.000128     1     1     1         Normal
# 19999  1.057252  193.3479  0.000128     1     1     1         Normal
#
# [20000 rows x 53 columns]

# %%
#преобразование метки времени из строки в тип timestamp
df['Timestamp'] = pd.to_datetime(df['Timestamp'].str.strip(), format="%d/%m/%Y %H:%M:%S %p")

# %%
df = df.set_index('Timestamp')

# %%
df['LIT101'][:10000].resample('1h').mean()
# Out:
# Timestamp
# 2015-12-22 04:00:00    202.121523
# 2015-12-22 05:00:00    287.186011
# 2015-12-22 06:00:00    327.408935
# 2015-12-22 07:00:00    352.526743
# Freq: h, Name: LIT101, dtype: float64

# %%
df.dropna(axis=1, how='all')
# Out:
#                        FIT101    LIT101  MV101  P101  P102    AIT201  \
# Timestamp
# 2015-12-22 04:30:00  0.000000  124.3135      1     1     1  251.9226
# 2015-12-22 04:30:01  0.000000  124.3920      1     1     1  251.9226
# 2015-12-22 04:30:02  0.000000  124.4705      1     1     1  251.9226
# 2015-12-22 04:30:03  0.000000  124.6668      1     1     1  251.9226
# 2015-12-22 04:30:04  0.000000  124.5098      1     1     1  251.9226
# ...                       ...       ...    ...   ...   ...       ...
# 2015-12-22 10:03:15  2.443391  503.4166      2     2     1  261.2791
# 2015-12-22 10:03:16  2.427057  503.4559      2     2     1  261.2791
# 2015-12-22 10:03:17  2.424815  503.2596      2     2     1  261.2791
# 2015-12-22 10:03:18  2.423854  503.2989      2     2     1  261.2791
# 2015-12-22 10:03:19  2.423854  503.2204      2     2     1  261.2791
#
#                        AIT202    AIT203    FIT201  MV201  ...  P501  P502  \
# Timestamp                                                 ...
# 2015-12-22 04:30:00  8.313446  312.7916  0.000000      1  ...     1     1
# 2015-12-22 04:30:01  8.313446  312.7916  0.000000      1  ...     1     1
# 2015-12-22 04:30:02  8.313446  312.7916  0.000000      1  ...     1     1
# 2015-12-22 04:30:03  8.313446  312.7916  0.000000      1  ...     1     1
# 2015-12-22 04:30:04  8.313446  312.7916  0.000000      1  ...     1     1
# ...                       ...       ...       ...    ...  ...   ...   ...
# 2015-12-22 10:03:15  8.339080  437.4263  2.460898      2  ...     2     1
# 2015-12-22 10:03:16  8.339080  437.4263  2.460898      2  ...     2     1
# 2015-12-22 10:03:17  8.339080  437.4007  2.460898      2  ...     2     1
# 2015-12-22 10:03:18  8.339080  437.3494  2.463204      2  ...     2     1
# 2015-12-22 10:03:19  8.339080  437.2212  2.463204      2  ...     2     1
#
#                          PIT501    PIT502    PIT503    FIT601  P601  P602  \
# Timestamp
# 2015-12-22 04:30:00    9.100231  0.000000    3.3485  0.000256     1     1
# 2015-12-22 04:30:01    9.100231  0.000000    3.3485  0.000256     1     1
# 2015-12-22 04:30:02    9.100231  0.000000    3.3485  0.000256     1     1
# 2015-12-22 04:30:03    9.100231  0.000000    3.3485  0.000256     1     1
# 2015-12-22 04:30:04    9.100231  0.000000    3.3485  0.000256     1     1
# ...                         ...       ...       ...       ...   ...   ...
# 2015-12-22 10:03:15  254.229700  1.105309  193.3479  0.000128     1     1
# 2015-12-22 10:03:16  254.229700  1.057252  193.3479  0.000128     1     1
# 2015-12-22 10:03:17  254.229700  1.057252  193.3479  0.000128     1     1
# 2015-12-22 10:03:18  254.229700  1.057252  193.3479  0.000128     1     1
# 2015-12-22 10:03:19  254.229700  1.057252  193.3479  0.000128     1     1
#
#                      P603  Normal/Attack
# Timestamp
# 2015-12-22 04:30:00     1         Normal
# 2015-12-22 04:30:01     1         Normal
# 2015-12-22 04:30:02     1         Normal
# 2015-12-22 04:30:03     1         Normal
# 2015-12-22 04:30:04     1         Normal
# ...                   ...            ...
# 2015-12-22 10:03:15     1         Normal
# 2015-12-22 10:03:16     1         Normal
# 2015-12-22 10:03:17     1         Normal
# 2015-12-22 10:03:18     1         Normal
# 2015-12-22 10:03:19     1         Normal
#
# [20000 rows x 52 columns]

# %%
df.shape
# Out:
# (20000, 52)

# %%
df.memory_usage(deep=True).sum() / 2**20
# Out:
# np.float64(8.983612060546875)

# %%
df.columns
# Out:
# Index(['FIT101', 'LIT101', 'MV101', 'P101', 'P102', 'AIT201', 'AIT202',
#        'AIT203', 'FIT201', 'MV201', 'P201', 'P202', 'P203', 'P204', 'P205',
#        'P206', 'DPIT301', 'FIT301', 'LIT301', 'MV301', 'MV302', 'MV303',
#        'MV304', 'P301', 'P302', 'AIT401', 'AIT402', 'FIT401', 'LIT401', 'P401',
#        'P402', 'P403', 'P404', 'UV401', 'AIT501', 'AIT502', 'AIT503', 'AIT504',
#        'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501', 'P502', 'PIT501',
#        'PIT502', 'PIT503', 'FIT601', 'P601', 'P602', 'P603', 'Normal/Attack'],
#       dtype='str')

# %%
filename = filename[:-5] + '_corr.csv'
filename
# Out:
# 'SWaT_Dataset_Normal_v_corr.csv'

# %%
df.to_csv(filename, index=True)

# %% [markdown]
# # 2. Анализ данных

# %% [markdown]
# ## 2.1. Загрузка обработанных данных

# %%
# %%time
df = pd.read_csv(filename, nrows=100_000, decimal=",")
df.head(5)
# Out:
# CPU times: total: 266 ms
# Wall time: 275 ms
#                 Timestamp  FIT101    LIT101  MV101  P101  P102    AIT201  \
# 0   22/12/2015 4:30:00 PM     0.0  124.3135      1     1     1  251.9226
# 1   22/12/2015 4:30:01 PM     0.0  124.3920      1     1     1  251.9226
# 2   22/12/2015 4:30:02 PM     0.0  124.4705      1     1     1  251.9226
# 3   22/12/2015 4:30:03 PM     0.0  124.6668      1     1     1  251.9226
# 4   22/12/2015 4:30:04 PM     0.0  124.5098      1     1     1  251.9226
#
#      AIT202    AIT203  FIT201  ...  P501  P502    PIT501  PIT502  PIT503  \
# 0  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 1  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 2  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 3  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 4  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
#
#      FIT601  P601  P602  P603  Normal/Attack
# 0  0.000256     1     1     1         Normal
# 1  0.000256     1     1     1         Normal
# 2  0.000256     1     1     1         Normal
# 3  0.000256     1     1     1         Normal
# 4  0.000256     1     1     1         Normal
#
# [5 rows x 53 columns]

# %% [markdown]
# ## 2.2. Статистики по данным

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Columns: 53 entries, Timestamp to Normal/Attack
# dtypes: float64(25), int64(26), str(2)
# memory usage: 40.4 MB

# %%
df.describe().T
# Out:
#             count        mean         std         min         25%         50%  \
# FIT101   100000.0    1.908744    1.102252    0.000000    1.252442    2.500400
# LIT101   100000.0  569.107220  147.484475  120.623700  503.298900  522.257900
# MV101    100000.0    1.743920    0.444573    0.000000    1.000000    2.000000
# P101     100000.0    1.764030    0.424606    1.000000    2.000000    2.000000
# P102     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# AIT201   100000.0  258.346346    3.226201  251.666200  256.600900  258.042800
# AIT202   100000.0    8.437302    0.181509    8.258652    8.344207    8.366317
# AIT203   100000.0  425.200663   67.591157  312.791600  335.683200  445.578100
# FIT201   100000.0    1.874890    1.040158    0.000000    2.434499    2.446545
# MV201    100000.0    1.763470    0.433365    0.000000    2.000000    2.000000
# P201     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P202     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P203     100000.0    1.762070    0.425818    1.000000    2.000000    2.000000
# P204     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P205     100000.0    1.337910    0.473000    1.000000    1.000000    1.000000
# P206     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# DPIT301  100000.0   16.616880    6.494480    0.016006   18.900060   19.722770
# FIT301   100000.0    1.843770    0.799098    0.000000    2.180380    2.208756
# LIT301   100000.0  869.829000  149.778398  132.818500  823.466700  910.063200
# MV301    100000.0    1.006100    0.117230    0.000000    1.000000    1.000000
# MV302    100000.0    1.810100    0.408901    0.000000    2.000000    2.000000
# MV303    100000.0    1.022830    0.179525    0.000000    1.000000    1.000000
# MV304    100000.0    1.026190    0.200361    0.000000    1.000000    1.000000
# P301     100000.0    1.017790    0.132188    1.000000    1.000000    1.000000
# P302     100000.0    1.817380    0.386357    1.000000    2.000000    2.000000
# AIT401   100000.0   29.573043   59.375025    0.000000    0.000000    0.000000
# AIT402   100000.0  189.191688   10.220958  169.238700  182.978700  186.952100
# FIT401   100000.0    1.675078    0.205179    0.000000    1.695704    1.701470
# LIT401   100000.0  845.423648  150.614481  130.389600  818.097900  882.389200
# P401     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P402     100000.0    1.985400    0.119946    1.000000    2.000000    2.000000
# P403     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P404     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# UV401    100000.0    1.985370    0.120067    1.000000    2.000000    2.000000
# AIT501   100000.0    7.830357    0.069924    7.411433    7.834081    7.845617
# AIT502   100000.0  176.295663    9.851977  166.290700  170.571700  173.647800
# AIT503   100000.0  265.914901    6.320241  252.243000  260.478100  267.687800
# AIT504   100000.0   13.078866   14.181503    7.344271   10.958730   11.266340
# FIT501   100000.0    1.684367    0.206155    0.001282    1.705588    1.710843
# FIT502   100000.0    1.246196    0.153283    0.000640    1.254611    1.263225
# FIT503   100000.0    0.730670    0.089796    0.001664    0.740262    0.741286
# FIT504   100000.0    0.304875    0.038467    0.000000    0.308426    0.310284
# P501     100000.0    1.984620    0.123059    1.000000    2.000000    2.000000
# P502     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# PIT501   100000.0  250.723246   29.519102    8.891951  253.428600  254.165600
# PIT502   100000.0    1.290828    0.306669    0.000000    1.009195    1.409669
# PIT503   100000.0  190.603111   22.838840    3.108177  192.578800  193.219700
# FIT601   100000.0    0.016211    0.157639    0.000000    0.000064    0.000128
# P601     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P602     100000.0    1.008910    0.093972    1.000000    1.000000    1.000000
# P603     100000.0    1.000000    0.000000    1.000000    1.000000    1.000000
#
#                 75%          max
# FIT101     2.596483     2.691285
# LIT101   676.835300   816.496600
# MV101      2.000000     2.000000
# P101       2.000000     2.000000
# P102       1.000000     1.000000
# AIT201   261.215100   266.341900
# AIT202     8.423353     8.988273
# AIT203   476.698300   567.469900
# FIT201     2.459616     2.487938
# MV201      2.000000     2.000000
# P201       1.000000     1.000000
# P202       1.000000     1.000000
# P203       2.000000     2.000000
# P204       1.000000     1.000000
# P205       2.000000     2.000000
# P206       1.000000     1.000000
# DPIT301   19.863630    21.099300
# FIT301     2.213624     2.358261
# LIT301   960.931500  1014.724000
# MV301      1.000000     2.000000
# MV302      2.000000     2.000000
# MV303      1.000000     2.000000
# MV304      1.000000     2.000000
# P301       1.000000     2.000000
# P302       2.000000     2.000000
# AIT401     0.000000   148.851300
# AIT402   190.746000   235.708800
# FIT401     1.705315     1.721334
# LIT401   925.762600  1003.935000
# P401       1.000000     1.000000
# P402       2.000000     2.000000
# P403       1.000000     1.000000
# P404       1.000000     1.000000
# UV401      2.000000     2.000000
# AIT501     7.859715     7.877339
# AIT502   176.544500   218.328600
# AIT503   270.507600   281.402200
# AIT504    11.650860   227.172500
# FIT501     1.715201     1.731223
# FIT502     1.275138     1.329192
# FIT503     0.743591     0.763691
# FIT504     0.310604     0.317010
# P501       2.000000     2.000000
# P502       1.000000     1.000000
# PIT501   254.966700   264.643700
# PIT502     1.569859     3.668343
# PIT503   193.940700   200.637600
# FIT601     0.000128     1.742415
# P601       1.000000     1.000000
# P602       1.000000     2.000000
# P603       1.000000     1.000000

# %% [markdown]
# ### 2.2.1. Определение типа признаков (непрерывные, булевые, категориальные)

# %%
const_columns = []
bool_columns = []
cat_columns = []

for column in df.columns:
    nunique = df[column].nunique()
    match nunique:
        case 1:    
            print(f"column {column} has only one value: {df[column].unique()[0]}")
            const_columns.append(column)
        case 2:    
            print(f"column {column} has only two values: {df[column].unique()}")
            bool_columns.append(column)
        case _ if nunique < 5: 
            print(f"column {column} has only {nunique} values: {df[column].unique()}")
            cat_columns.append(column)
# Out:
# column MV101 has only 3 values: [1 0 2]
# column P101 has only two values: [1 2]
# column P102 has only one value: 1
# column MV201 has only 3 values: [1 0 2]
# column P201 has only one value: 1
# column P202 has only one value: 1
# column P203 has only two values: [1 2]
# column P204 has only one value: 1
# column P205 has only two values: [1 2]
# column P206 has only one value: 1
# column MV301 has only 3 values: [1 0 2]
# column MV302 has only 3 values: [1 0 2]
# column MV303 has only 3 values: [1 0 2]
# column MV304 has only 3 values: [1 0 2]
# column P301 has only two values: [1 2]
# column P302 has only two values: [1 2]
# column P401 has only one value: 1
# column P402 has only two values: [1 2]
# column P403 has only one value: 1
# column P404 has only one value: 1
# column UV401 has only two values: [1 2]
# column P501 has only two values: [1 2]
# column P502 has only one value: 1
# column P601 has only one value: 1
# column P602 has only two values: [1 2]
# column P603 has only one value: 1
# column Normal/Attack has only one value: Normal

# %% [markdown]
# ### 2.2.2. Удаление признаков-констант

# %%
df = df.drop(const_columns, axis = 1)
df[bool_columns+cat_columns] = df[bool_columns+cat_columns].astype("category")
df.info(verbose=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Columns: 41 entries, Timestamp to P602
# dtypes: category(15), float64(25), str(1)
# memory usage: 21.3 MB

# %%
df.head()
# Out:
#                 Timestamp  FIT101    LIT101 MV101 P101    AIT201    AIT202  \
# 0   22/12/2015 4:30:00 PM     0.0  124.3135     1    1  251.9226  8.313446
# 1   22/12/2015 4:30:01 PM     0.0  124.3920     1    1  251.9226  8.313446
# 2   22/12/2015 4:30:02 PM     0.0  124.4705     1    1  251.9226  8.313446
# 3   22/12/2015 4:30:03 PM     0.0  124.6668     1    1  251.9226  8.313446
# 4   22/12/2015 4:30:04 PM     0.0  124.5098     1    1  251.9226  8.313446
#
#      AIT203  FIT201 MV201  ...    FIT501    FIT502    FIT503  FIT504  P501  \
# 0  312.7916     0.0     1  ...  0.001538  0.001409  0.001664     0.0     1
# 1  312.7916     0.0     1  ...  0.001538  0.001409  0.001664     0.0     1
# 2  312.7916     0.0     1  ...  0.001538  0.001409  0.001664     0.0     1
# 3  312.7916     0.0     1  ...  0.001538  0.001409  0.001664     0.0     1
# 4  312.7916     0.0     1  ...  0.001538  0.001409  0.001664     0.0     1
#
#      PIT501 PIT502  PIT503    FIT601 P602
# 0  9.100231    0.0  3.3485  0.000256    1
# 1  9.100231    0.0  3.3485  0.000256    1
# 2  9.100231    0.0  3.3485  0.000256    1
# 3  9.100231    0.0  3.3485  0.000256    1
# 4  9.100231    0.0  3.3485  0.000256    1
#
# [5 rows x 41 columns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'].str.strip(), format = "%d/%m/%Y %I:%M:%S %p")

# %%
df = df.set_index('Timestamp')

# %%
df['LIT101'][:10000].rolling("1h").mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Timestamp'>

# %% [markdown]
# ## 2.4. Анализ непрерывных и категориальных признаков

# %%
df.describe().T
# Out:
#             count        mean         std         min         25%         50%  \
# FIT101   100000.0    1.908744    1.102252    0.000000    1.252442    2.500400
# LIT101   100000.0  569.107220  147.484475  120.623700  503.298900  522.257900
# AIT201   100000.0  258.346346    3.226201  251.666200  256.600900  258.042800
# AIT202   100000.0    8.437302    0.181509    8.258652    8.344207    8.366317
# AIT203   100000.0  425.200663   67.591157  312.791600  335.683200  445.578100
# FIT201   100000.0    1.874890    1.040158    0.000000    2.434499    2.446545
# DPIT301  100000.0   16.616880    6.494480    0.016006   18.900060   19.722770
# FIT301   100000.0    1.843770    0.799098    0.000000    2.180380    2.208756
# LIT301   100000.0  869.829000  149.778398  132.818500  823.466700  910.063200
# AIT401   100000.0   29.573043   59.375025    0.000000    0.000000    0.000000
# AIT402   100000.0  189.191688   10.220958  169.238700  182.978700  186.952100
# FIT401   100000.0    1.675078    0.205179    0.000000    1.695704    1.701470
# LIT401   100000.0  845.423648  150.614481  130.389600  818.097900  882.389200
# AIT501   100000.0    7.830357    0.069924    7.411433    7.834081    7.845617
# AIT502   100000.0  176.295663    9.851977  166.290700  170.571700  173.647800
# AIT503   100000.0  265.914901    6.320241  252.243000  260.478100  267.687800
# AIT504   100000.0   13.078866   14.181503    7.344271   10.958730   11.266340
# FIT501   100000.0    1.684367    0.206155    0.001282    1.705588    1.710843
# FIT502   100000.0    1.246196    0.153283    0.000640    1.254611    1.263225
# FIT503   100000.0    0.730670    0.089796    0.001664    0.740262    0.741286
# FIT504   100000.0    0.304875    0.038467    0.000000    0.308426    0.310284
# PIT501   100000.0  250.723246   29.519102    8.891951  253.428600  254.165600
# PIT502   100000.0    1.290828    0.306669    0.000000    1.009195    1.409669
# PIT503   100000.0  190.603111   22.838840    3.108177  192.578800  193.219700
# FIT601   100000.0    0.016211    0.157639    0.000000    0.000064    0.000128
#
#                 75%          max
# FIT101     2.596483     2.691285
# LIT101   676.835300   816.496600
# AIT201   261.215100   266.341900
# AIT202     8.423353     8.988273
# AIT203   476.698300   567.469900
# FIT201     2.459616     2.487938
# DPIT301   19.863630    21.099300
# FIT301     2.213624     2.358261
# LIT301   960.931500  1014.724000
# AIT401     0.000000   148.851300
# AIT402   190.746000   235.708800
# FIT401     1.705315     1.721334
# LIT401   925.762600  1003.935000
# AIT501     7.859715     7.877339
# AIT502   176.544500   218.328600
# AIT503   270.507600   281.402200
# AIT504    11.650860   227.172500
# FIT501     1.715201     1.731223
# FIT502     1.275138     1.329192
# FIT503     0.743591     0.763691
# FIT504     0.310604     0.317010
# PIT501   254.966700   264.643700
# PIT502     1.569859     3.668343
# PIT503   193.940700   200.637600
# FIT601     0.000128     1.742415

# %% [markdown]
# В категориальные запишем в т.ч. булевые, для упрощения. Остальные - в непрерывные

# %%
cat_columns = bool_columns+cat_columns
cont_columns = list(set(df.columns) - set(cat_columns))
cont_columns
# Out:
# ['AIT502',
#  'AIT203',
#  'AIT503',
#  'LIT401',
#  'FIT501',
#  'AIT504',
#  'FIT503',
#  'PIT501',
#  'LIT101',
#  'DPIT301',
#  'FIT201',
#  'FIT301',
#  'AIT501',
#  'AIT402',
#  'FIT504',
#  'FIT502',
#  'PIT503',
#  'AIT202',
#  'AIT401',
#  'LIT301',
#  'FIT101',
#  'AIT201',
#  'FIT601',
#  'PIT502',
#  'FIT401']

# %% [markdown]
# ### 2.4.1. Непрерывные признаки

# %% [markdown]
# Формула для оценки плотности ядра:
#
# $$\hat{f}_h(x) = \frac{1}{n}\sum_{i=1}^{n} K_h(x - x_i) = \frac{1}{nh}\sum_{i=1}^{n} K\!\left(\frac{x - x_i}{h}\right)$$
#
#
# В случае гауссова ядра (только этот вариант поддерживает Pandas)
#
# $$\hat{f}_h(x) = \frac{1}{n}\sum_{i=1}^{n} \frac{1}{h\sqrt{2\pi}} \exp\!\left(\frac{-(x-x_i)^2}{2h^2}\right)$$

# %%
# %%time

#определение возможного распределения значений величины
df[cont_columns].plot(
    kind='kde', 
    figsize=(10,50),
    subplots=True,
    sharex=False, 
    title='Kernel Density Estimation',
    legend=True
)

plt.show()
# Out:
# CPU times: total: 1min
# Wall time: 24.9 s

# %%
df[cont_columns].boxplot(figsize=(20,10))
plt.title("Диаграмма размаха")
plt.show()

# %%
df[['FIT501']].boxplot(figsize=(20,10))
plt.show()

# %%
df['FIT501'].plot(figsize=(20,10))
plt.show()

# %%
df['FIT501'].loc['2015-12-22 17:00:00':].plot(figsize=(20,10))
plt.show()

# %%
df['FIT501'].loc['2015-12-22 16:54:00':'2015-12-22 16:57:00'].plot(figsize=(20,10))
plt.show()

# %% [markdown]
# ### 2.4.2. Категориальные/булевые признаки

# %%
ncols = 8
nrows = len(cat_columns) // ncols
if len(cat_columns) % ncols != 0: nrows += 1

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(20,10))


for row, ax_row in enumerate(axes):
    for ax, col in zip(ax_row, cat_columns[row*ncols:(row+1)*ncols]):
        df[col].value_counts(normalize=True).plot.bar(ax=ax, title=col)

# %% [markdown]
# ### 2.4.2. Анализ корреляции

# %%
sns.heatmap(df[cont_columns].corr(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
cg = sns.clustermap(
    df[cont_columns].corr(),
    method='ward',         # метод кластеризации
    metric='euclidean',
    cmap='YlGnBu',
    center=0,
    vmin=-1, vmax=1,
    annot=False,
    #fmt='.2f',
    #linewidths=0.5,
    #figsize=(12, 10),
    #dendrogram_ratio=0.15, # размер дендрограммы относительно карты
    #cbar_pos=(1.02, 0.3, 0.03, 0.4),  # положение colorbar
)
plt.show()

# %%
#plt.figure(figsize=(10,10))
sns.heatmap(df[sorted(cont_columns, key=lambda x: x[3])].corr(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
df_corr = df[sorted(cont_columns, key=lambda x: x[3])].corr()

# %% [markdown]
# Найдем наиболее скоррелированные признаки

# %%
from itertools import combinations

unique_pairs = list(combinations(df_corr.columns, 2))
most_correlated = pd.DataFrame(columns=['1st', '2nd', 'value'])

for row, col in unique_pairs:
    corr_value = df_corr.loc[row, col]
    if corr_value >= 0.75:
        most_correlated.loc[most_correlated.shape[0]] = pd.Series({'1st': row, '2nd': col, 'value': corr_value})

most_correlated.sort_values('value', ascending=False)
# Out:
#        1st      2nd     value
# 7   FIT401   FIT501  0.999943
# 24  PIT501   PIT503  0.999844
# 18  FIT503   PIT501  0.997932
# 9   FIT401   PIT501  0.996814
# 14  FIT501   PIT501  0.996753
# 21  FIT503   PIT503  0.996732
# 13  FIT501   FIT503  0.996705
# 8   FIT401   FIT503  0.996682
# 12  FIT401   PIT503  0.996253
# 17  FIT501   PIT503  0.996172
# 16  FIT501   FIT502  0.995574
# 11  FIT401   FIT502  0.995528
# 19  FIT503   FIT504  0.992285
# 20  FIT503   FIT502  0.991923
# 23  PIT501   FIT502  0.990791
# 27  FIT502   PIT503  0.989842
# 22  PIT501   FIT504  0.983184
# 15  FIT501   FIT504  0.982953
# 10  FIT401   FIT504  0.982789
# 25  FIT504   FIT502  0.980291
# 26  FIT504   PIT503  0.980001
# 2   FIT301  DPIT301  0.975995
# 6   AIT402   AIT502  0.960795
# 5   LIT401   AIT501  0.872155
# 3   LIT301   LIT401  0.863943
# 4   LIT301   AIT501  0.863477
# 0   AIT203   AIT503  0.803058
# 1   AIT201   AIT503   0.79162

# %% [markdown]
# # 3. Работа с временным рядом

# %% [markdown]
# ## 3.1. Визуализация пропущенных значений

# %% [markdown]
# Можно использовать тепловую карту из sns и метод isna для датафрейма, но мы будем использовать модуль missingno - так проще, но его надо установить
#
# pip install missingno

# %%
import missingno

missingno.matrix(df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# FIT101     0
# LIT101     0
# MV101      0
# P101       0
# AIT201     0
# AIT202     0
# AIT203     0
# FIT201     0
# MV201      0
# P203       0
# P205       0
# DPIT301    0
# FIT301     0
# LIT301     0
# MV301      0
# MV302      0
# MV303      0
# MV304      0
# P301       0
# P302       0
# AIT401     0
# AIT402     0
# FIT401     0
# LIT401     0
# P402       0
# UV401      0
# AIT501     0
# AIT502     0
# AIT503     0
# AIT504     0
# FIT501     0
# FIT502     0
# FIT503     0
# FIT504     0
# P501       0
# PIT501     0
# PIT502     0
# PIT503     0
# FIT601     0
# P602       0
# dtype: int64

# %% [markdown]
# пропущенных значений нет, можно было бы это понять из info, но если бы были - эта визуализация бы нам помогла

# %% [markdown]
# ## 3.2. Ресэмплирование и сглаживание

# %%
df.head(5)
# Out:
#                      FIT101    LIT101 MV101 P101    AIT201    AIT202  \
# Timestamp
# 2015-12-22 16:30:00     0.0  124.3135     1    1  251.9226  8.313446
# 2015-12-22 16:30:01     0.0  124.3920     1    1  251.9226  8.313446
# 2015-12-22 16:30:02     0.0  124.4705     1    1  251.9226  8.313446
# 2015-12-22 16:30:03     0.0  124.6668     1    1  251.9226  8.313446
# 2015-12-22 16:30:04     0.0  124.5098     1    1  251.9226  8.313446
#
#                        AIT203  FIT201 MV201 P203  ...    FIT501    FIT502  \
# Timestamp                                         ...
# 2015-12-22 16:30:00  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 16:30:01  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 16:30:02  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 16:30:03  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 16:30:04  312.7916     0.0     1    1  ...  0.001538  0.001409
#
#                        FIT503  FIT504 P501    PIT501 PIT502  PIT503    FIT601  \
# Timestamp
# 2015-12-22 16:30:00  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 16:30:01  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 16:30:02  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 16:30:03  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 16:30:04  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
#
#                     P602
# Timestamp
# 2015-12-22 16:30:00    1
# 2015-12-22 16:30:01    1
# 2015-12-22 16:30:02    1
# 2015-12-22 16:30:03    1
# 2015-12-22 16:30:04    1
#
# [5 rows x 40 columns]

# %% [markdown]
# Изначально данные в датафрейме идут каждую секунду.
#
# Предположим, что наши процессы достаточно инерционные и нам хватает периода в 1 минуту - это будет влиять на скорость обработки данных, их объем.
# При помощи функции resample мы будем аггрегировать данные по 1 минуте, считая среднее значение за минуту. Применим это преобразование только к непрерывным признакам, т.к. для категориальных нет такого понятия как "среднее"

# %%
df_1min = df[cont_columns].resample('1min').mean()
df_1min.head(5)
# Out:
#                          AIT502      AIT203      AIT503      LIT401    FIT501  \
# Timestamp
# 2015-12-22 16:30:00  175.408857  312.933878  260.702400  133.086390  0.001538
# 2015-12-22 16:31:00  175.632332  313.296585  260.702400  132.646765  0.001538
# 2015-12-22 16:32:00  175.797222  313.669147  260.756885  132.498727  0.001538
# 2015-12-22 16:33:00  175.976200  313.957082  260.755820  132.446173  0.001538
# 2015-12-22 16:34:00  176.083923  314.210027  260.766500  132.327617  0.001538
#
#                          AIT504    FIT503    PIT501      LIT101   DPIT301  \
# Timestamp
# 2015-12-22 16:30:00  123.381805  0.001664  9.079136  124.158442  2.560983
# 2015-12-22 16:31:00  123.347197  0.001664  9.068188  123.908527  2.561677
# 2015-12-22 16:32:00  123.340152  0.001664  9.068188  123.548057  2.564185
# 2015-12-22 16:33:00  123.355538  0.001664  9.068188  123.040390  2.564185
# 2015-12-22 16:34:00  123.354890  0.001664  9.068188  123.389078  2.564185
#
#                      ...    FIT502    PIT503    AIT202  AIT401      LIT301  \
# Timestamp            ...
# 2015-12-22 16:30:00  ...  0.001409  3.348500  8.310001     0.0  137.999468
# 2015-12-22 16:31:00  ...  0.001409  3.348500  8.309750     0.0  137.562883
# 2015-12-22 16:32:00  ...  0.001409  3.291090  8.311182     0.0  136.653002
# 2015-12-22 16:33:00  ...  0.001409  3.260382  8.310124     0.0  137.310540
# 2015-12-22 16:34:00  ...  0.001409  3.255843  8.310087     0.0  136.822560
#
#                        FIT101      AIT201    FIT601  PIT502  FIT401
# Timestamp
# 2015-12-22 16:30:00  0.000000  251.922600  0.000256     0.0     0.0
# 2015-12-22 16:31:00  0.000016  251.922600  0.000256     0.0     0.0
# 2015-12-22 16:32:00  0.000000  251.916190  0.000256     0.0     0.0
# 2015-12-22 16:33:00  0.000000  251.841938  0.000256     0.0     0.0
# 2015-12-22 16:34:00  0.000000  251.841435  0.000256     0.0     0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# Также мы можем применить к этим данным сглаживание

# %%
df['AIT503']
# Out:
# Timestamp
# 2015-12-22 16:30:00    260.7024
# 2015-12-22 16:30:01    260.7024
# 2015-12-22 16:30:02    260.7024
# 2015-12-22 16:30:03    260.7024
# 2015-12-22 16:30:04    260.7024
#                          ...
# 2015-12-23 20:16:35    254.8705
# 2015-12-23 20:16:36    254.8705
# 2015-12-23 20:16:37    254.8705
# 2015-12-23 20:16:38    254.9987
# 2015-12-23 20:16:39    254.9987
# Name: AIT503, Length: 100000, dtype: float64

# %%
df_rolling = df[cont_columns].rolling(60).mean()

# %%
col = 'FIT501'

plt.figure(figsize=(20,5))

plt.plot(df[col].loc['2015-12-22 17:30:00':'2015-12-22 18:30:00'], alpha=0.5, label='original')
plt.plot(df_rolling[col].loc['2015-12-22 17:30:00':'2015-12-22 18:30:00'], label='rolling')
plt.plot(df_1min[col].loc['2015-12-22 17:30:00':'2015-12-22 18:30:00'], label='resample')

plt.title('Сглаженный, ресэмплированный и оригинальный графики')
plt.legend()
plt.show()
